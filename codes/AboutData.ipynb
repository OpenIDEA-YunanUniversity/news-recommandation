# %%
import pickle
import pandas as pd

# %%
artiles = open('../data/articles_embeddings.pickle','rb')
data = pickle.load(artiles)

# %%
data = pd.DataFrame(data)
data['click_article_id'] = data.index

# %%
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.161183 -0.957233 -0.137944  0.050855  0.830055  0.901365 -0.335148
# 1 -0.523216 -0.974058  0.738608  0.155234  0.626294  0.485297 -0.715657
# 2 -0.619619 -0.972960 -0.207360 -0.128861  0.044748 -0.387535 -0.730477
# 3 -0.740843 -0.975749  0.391698  0.641738 -0.268645  0.191745 -0.825593
# 4 -0.279052 -0.972315  0.685374  0.113056  0.238315  0.271913 -0.568816
#
#           7         8         9        ...              241       242  \
# 0 -0.559561 -0.500603  0.165183        ...         0.313999  0.636412
# 1 -0.897996 -0.359747  0.398246        ...         0.823124  0.412688
# 2 -0.066126 -0.754899 -0.242004        ...         0.473184  0.377866
# 3 -0.710591 -0.040099 -0.110514        ...         0.036040  0.480029
# 4  0.341194 -0.600554 -0.125644        ...         0.809268  0.427521
#
#         243       244       245       246       247       248       249  \
# ...

# %%
click = pd.read_csv('../data/click/clicks_hour_000.csv')

# %%
df = pd.DataFrame()
df = df.append(click)

# %%
df.col
# Out:
#       user_id        session_id  session_start  session_size  \
# 0           0    15068254230001  1506825423000             2
# 1           0    15068254230001  1506825423000             2
# 2           1    15068254260002  1506825426000             2
# 3           1    15068254260002  1506825426000             2
# 4           2    15068254350003  1506825435000             2
# 5           2    15068254350003  1506825435000             2
# 6           3    15068254420004  1506825442000             2
# 7           3    15068254420004  1506825442000             2
# 8           4    15068255280005  1506825528000             2
# 9           4    15068255280005  1506825528000             2
# 10          5    15068255410006  1506825541000             3
# 11          5    15068255410006  1506825541000             3
# 12          5    15068255410006  1506825541000             3
# 13          6    15068255530007  1506825553000             2
# ...
